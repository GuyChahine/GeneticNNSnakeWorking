# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go

# %%
infos = pd.read_pickle("models/information.pkl")
px.line(infos, x="datetime", y="fitness")
